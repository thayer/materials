# %%
'''
Author:
    Erfan Azad (erfan@dartmouth.edu)

Date:
    27 January 2017
    
Description:
    This script opens a CSV database of products
    and automatically creates a .md file with
    corresponding YAML for each product.
'''

import csv
    
def makeProductFileUsingRow(row, outputFilename):
    content = "---\n" #initialize YAML 
    content += "product_name: \"{}\"\n".format(row[4].strip()) #Name
    print(row[4].strip())
    content += "index_letter: {}\n".format(row[4].strip()[0].upper().strip()) #Index letter
    content += "class: {}\n".format(row[2].strip()) #Class
    content += "subclass: {}\n".format(row[3].strip()) #Subclass

    #Componenets
    content += "components:\n"
    comps = row[7].split("-")[1:]
    masses = [mass.strip().split("_") for mass in row[10].split("-")[1:]]
    materials = [material.strip().split("_") for material in row[8].split("-")[1:]]
    processes = [process.strip().split("_") for process in row[9].split("-")[1:]]
    counter = 1
    for comp in comps:
        content += "  - {}:\n".format(comp.strip())
        for mass in masses:
            if (int(mass[0]) == counter):
                content += "    - mass: {}\n".format(mass[1])
        content += "    - materials:\n"
        for material in materials:
            if (int(material[0]) == counter and material[1] != ""):
                content += "      - {}\n".format(material[1])
        content += "    - processes:\n"
        for process in processes:
            if (int(process[0]) == counter and process[1] != ""):
                content += "      - {}\n".format(process[1])
        counter += 1

    content += "manufacturer: \"{}\"\n".format(row[11].strip()) #Manufacturer
    content += "cost: {}\n".format(row[12].strip()) #Cost
    content += "DOP: {}\n".format(row[14].strip()) #Date of purchase
    content += "POP: {}\n".format(row[13].strip()) #Place of purchase
    content += "product_description: \"{}\"\n".format(row[15].strip()) #Product Description
    content += "materials_and_processes_description: \"{}\"\n".format(row[16].strip())  # Materials and Processes description
    if(row[0].strip() == ""):
        content += "primary_photo_path: \"\"\n"    #Primary Photo Path
    else:
        content += "primary_photo_path: /photos/{}.jpg\n".format(row[0].strip().split("/")[0].strip()) #Primary Photo Path
    content += "link_to_manufacturer_website: \"{}\"\n".format(row[18].strip()) #Link to manufacturer
    content += "additional_photos:\n"
    if(row[1].strip() == "N/A" or row[1].strip() == ""):
        content += "  - additional_photo_path: \"\"\n"   #No Additional Photo
    else:
        photos = row[1].strip().split('-')[1:]
        for photo in photos:
            content += "  - additional_photo_path: /photos/{}.jpg\n".format(photo.strip()) #Additional Photo
    
    content += "HIMvideos:\n"                      # How it is made videos
    HIMvideos = row[19].strip().split("*")[1:]
    for video in HIMvideos:
        content += "  - {}\n".format(video.strip())
        
    content += "---\n" #End of YAML
    
    output = open(outputFilename, 'w')
    output.write(content)
    output.close()
    
    
def main():
    raw = open("Products Information Spreadsheet - Sheet1.csv", 'r')
    data = csv.reader(raw, delimiter=',')

    outputFilenameCounter = 3000
    for row in data:
        if outputFilenameCounter > 3178:
            break; # the rest of the product datasheet is not ready yet!
        print(outputFilenameCounter)
        if (outputFilenameCounter != 3000): #ignore the header row
            filename = "../_products/{}.md".format(outputFilenameCounter)
#             filename = "test/{}.md".format(outputFilenameCounter)
            makeProductFileUsingRow(row, filename)
        else:
            print(row)
        outputFilenameCounter += 1

# %%
main()
# Out:
# 3000
# ['Picture #', 'Additional Photos', 'Product Class', 'Product Subclass', 'Name', 'Location in Cabinets', 'Image Credit', 'Components', 'Materials', 'Processes', 'Mass', 'Manufacturer', 'Cost', 'Place of Purchase', 'Date of Purchase', 'Product Description', 'Materials and Processes Description', 'Packaging Labels (including warnings and advertisements)', 'Links to Materials, Processes, and Manufacturer/Product Website', "How It's Made Video", 'QR code (yes - green, no - red)']
# 3001
# Measuring Cups (Silicone)
# 3002
# Skis (Vokl racing)
# 3003
# Bicycle Tire
# 3004
# Measuring Cup (4-cup, Mainstays)
# 3005
# Bicycle Inner Tube
# 3006
# Tape (Joe's Sticky Stuff)
# 3007
# Broom (palm, silk, bamboo handle, copper wire)
# 3008
# Broom (palmyra fibers, wooden handle)
# 3009
# Bamboo Basket
# 3010
# Glass Tile (Yellow, Brown, White, Black, and Green)
# 3011
# Glass Tile (Black and White)
# 3012
# Glass tile (Black, Red, White, and Gray
# 3013
# Sponge Scrubber (Cellulose Sponge)
# 3014
# Twine (Hemp)
# 3015
# Recorder
# 3016
# Oven Thermometer)
# 3017
# Scrubber Sponge (Wool, Baudelaire)
# 3018
# Kitchen Spatula (Bamboo)
# 3019
# Rolling Pin (Wood)
# 3020
# Hammer (Hickory Wood Handle, Workforce)
# 3021
# Play-doh
# 3022
# Tealight
# 3023
# Clay Brown Sugar Saver
# 3024
# Rubber Band (Natural Rubber)
# 3025
# Eraser
# 3026
# Spring
# 3027
# Spring
# 3028
# Spring
# 3029
# Spring
# 3030
# Spring
# 3031
# Spring (With hooks)
# 3032
# Balloon (natural rubber -latex)
# 3033
# Can (Aluminum)
# 3034
# iPhone Case
# 3035
# Spring
# 3036
# Bottle (glass)
# 3037
# Banana Leaf Plate
# 3038
# Bamboo (Square Cross Section)
# 3039
# Knitting Needles (Bamboo)
# 3040
# Sandwich Bag (Bees Wax Cotton Cloth)
# 3041
# Door Handle
# 3042
# Spatula (Bamboo)
# 3043
# Spoon (Bamboo)
# 3044
# Skewer Sticks (Bamboo)
# 3045
# Cutlery (Polypropylene, 100% recycled, green)
# 3046
# Spring
# 3047
# Spring
# 3048
# Spring
# 3049
# Cutlery (Ingeo Plastic)
# 3050
# Cutlery (Polypropylene, white, Shurfine)
# 3051
# Cutlery (Fork (plastic)
# 3052
# Cutlery (plastic)
# 3053
# Cycling helmet (red, Schwinn)
# 3054
# Kitchen Spatula (Silicone)
# 3055
# Turner (Stainless Steel, Nylon, slotted)
# 3056
# Spatula (metal)
# 3057
# Cooking Pot (Enamel on Steel)
# 3058
# Frying Pan (T-fal)
# 3059
# Frying Pan (Green+Life)
# 3060
# Frying Pan (Cast Iron)
# 3061
# Marble Sheet
# 3062
# Paring Knife (Wusthof)
# 3063
# Peeler (Rosenhaus Swiss)
# 3064
# Peeler (Kuhn Rikon)
# 3065
# Arrowhead (Obsidian)
# 3066
# Slate Tile
# 3067
# Paring Cutlery Set (3-piece, ceramic, Hampton Forge)
# 3068
# Paring Knife (ceramic, Kyocera)
# 3069
# Peeler (Ceramic Blade, Kyocera)
# 3070
# Cutlery (Polypropylene, white, Creative Convention)
# 3071
# Coffee Brewing Cone (polypropylene)
# 3072
# Coffee Filter for Cone (Bleached Paper)
# 3073
# Coffee Filter for Cone (Unbleached Paper)
# 3074
# Disposable Cutlery (Starch, 100%)
# 3075
# Coffee Filter (Bamboo)
# 3076
# Coffee Filter System
# 3077
# Household Gloves (Natural Rubber)
# 3078
# Tea Filters (Unbleached Paper)
# 3079
# Scrubber Sponge (Cellulose, Natural Value)
# 3080
# Coffee Filter (for JavaJig, Melitta)
# 3081
# Switch Plate
# 3082
# Mug Cozie (PET)
# 3083
# Scrubber Sponge (Loofah Scrubber, Cellulose Sponge)
# 3084
# Scrubber Sponge (Cellulose, Western Family)
# 3085
# Gate Valve
# 3086
# Aluminum Foil (virgin)
# 3087
# Aluminum Foil (recycled)
# 3088
# Sandwich Bags (PET)
# 3089
# Sandwich Bags (Wax Paper)
# 3090
# Sandwich Bags (Unbleached Paper)
# 3091
# Sandwich Bags (Low Density Polyethylene)
# 3092
# Bowl Scraper (silicone)
# 3093
# Trivet (Silicone)
# 3094
# Kitchen Tongs (Silicone)
# 3095
# Spatula (Silicone, Core Kitchen)
# 3096
# Basting Brush (silicone)
# 3097
# Cutting Board (Wood Fiber, Epicurean)
# 3098
# Tea Ball Infuser (Stainless Steel)
# 3099
# Knitting Needles (Metal)
# 3100
# Measuring Cup (2.5-cup, Greenbrier)
# 3101
# Baseball (Markwort)
# 3102
# Softball
# 3103
# Photographic Film Roll
# 3104
# Zipper (Cotton, Nylon)
# 3105
# Cutlery (Birchwood)
# 3106
# Table Tennis Ball (Celluloid)
# 3107
# Zipper (blue, YKK)
# 3108
# Chocolate
# 3109
# Maple Syrup
# 3110
# Ice Cream
# 3111
# Sugar (Rock)
# 3112
# Belt (Leather (brown),Dockers)
# 3113
# Belt (Leather (black), Dockers)
# 3114
# Bowl (Ceramic)
# 3115
# Bowl (Glass Ceramic)
# 3116
# Bowl (Glass)
# 3117
# Crockery Pot (White)
# 3118
# Cutlery (Aluminum Alloy, Sea to Summit)
# 3119
# Flashlight (LED, L.L. Bean)
# 3120
# Hammer (Steel, Rubber handle)
# 3121
# Lightbulb (Halogen, 50W, 12V, Sylvania)
# 3122
# Lightbulb (Incandescent, 60W, 120V, Sylvania)
# 3123
# Magnesium Fire Starter
# 3124
# Flint Stones Fire Starter
# 3125
# Racquet Balls (3 Penn)
# 3126
# Spark Plug
# 3127
# Spork (Polymer)
# 3128
# Spork (Titanium)
# 3129
# Tennis Balls (3 Penn)
# 3130
# Loofah Bath Brush
# 3131
# D4 Batteries (Energizer)
# 3132
# Grater
# 3133
# Muffin Pan (Red, Mrs. Anderson's Baking)
# 3134
# Maple Sugar
# 3135
# Cocoa Powder (Unsweetened, Natural, Scharffen Berger)
# 3136
# Virgin Mold Sand
# 3137
# Magnetic Iron Filings (12oz)
# 3138
# Ice Cream Scooper (OXO)
# 3139
# Key Ring (Bolt Snap)
# 3140
# Mixed Mold Sand
# 3141
# Cocoa Butter (Venchi)
# 3142
# Golf Balls
# 3143
# Glue Tape
# 3144
# Bicycle Bell (Small, Huffy)
# 3145
# Lightbulbs (Vibration Resistant, 60W, 120V, 650Lumins, GE)
# 3146
# Cocoa Nibs
# 3147
# Cocoa Beans
# 3148
# Milk Powder
# 3149
# Baking Cups (CupcakeCreations)
# 3150
# Baking Cups (Mrs. Anderson's Baking
# 3151
# LED Fiber Optic Centerpiece Lamp
# 3152
# Fiber Optic FingerBeams Finger Ring Lights
# 3153
# Metal Scoop
# 3154
# Spring Clamp
# 3155
# Legos
# 3156
# Coat Hanger (Black, cast iron)
# 3157
# French Press
# 3158
# Adjustable Wrench (cast aluminum)
# 3159
# Nakiri Mini Knife
# 3160
# Basting Brush (red and white, silicone)
# 3161
# Cotton Cloth
# 3162
# Honey
# 3163
# Baking Brushes
# 3164
# Invert Sugar
# 3165
# Reusable Coffee Filter
# 3166
# Bamboo Cutting Board
# 3167
# Pinky Bounce Ball
# 3168
# Milk Chocolate
# 3169
# Badminton Shuttlecocks
# 3170
# Pigments Set (Kremer)
# 3171
# Comb
# 3172
# Chopsticks
# 3173
# Mystery Density Set (eisco)
# 3174
# Pottery Tool Kit
# 3175
# Bell
# 3176
# Record
# 3177
# Rainbow Xylophone
# 3178
# Clay Set
